# %%
import numpy
import random

import getml

getml.engine.set_project('biodegradability')
# Out:
# Loading existing project 'biodegradability'

# %% [markdown]
# Establish a connection to the remote MariaDB database.

# %%
getml.database.connect_mysql(
    host="relational.fit.cvut.cz",
    port=3306,
    dbname="Biodegradability",
    user="guest",
    password="relational",
    time_formats=['%Y/%m/%d']
)

# %% [markdown]
# Load all required tables and upload them into the getML engine.

# %%
atom = getml.data.DataFrame.from_db('atom','atom')
bond = getml.data.DataFrame.from_db('bond','bond')
gmember = getml.data.DataFrame.from_db('gmember','gmember')
group = getml.data.DataFrame.from_db('group','group')
molecule = getml.data.DataFrame.from_db('molecule','molecule')

# %% [markdown]
# Annotate the loaded data.

# %%
molecule.set_role('molecule_id', getml.data.roles.join_key)
molecule.set_role('mweight', getml.data.roles.numerical)
molecule.set_role('activity', getml.data.roles.numerical)
molecule.set_role('logp', getml.data.roles.target)

atom.set_role('atom_id', getml.data.roles.join_key)
atom.set_role('molecule_id', getml.data.roles.join_key)
atom.set_role('type', getml.data.roles.categorical)

bond.set_role('atom_id', getml.data.roles.join_key)
bond.set_role('atom_id2', getml.data.roles.join_key)
bond.set_role('type', getml.data.roles.categorical)

gmember.set_role('atom_id', getml.data.roles.join_key)
gmember.set_role('group_id', getml.data.roles.join_key)

group.set_role('group_id', getml.data.roles.join_key)
group.set_role('type', getml.data.roles.categorical)

# %% [markdown]
# Split the molecule data table into training, validation, and test set.

# %%
percentage_training = 0.5
percentage_validation = 0.25
# Add a column containing a shuffled version of the row numbers used to split the data at random.
molecule.add(numpy.array(random.sample(range(0, molecule.shape[0]), k=molecule.shape[0])), 'index')

molecule_training = molecule.where('molecule_training', 
                                   molecule['index'] < molecule.shape[0]*percentage_training)
molecule_validation = molecule.where('molecule_validation',
                                     (molecule['index'] > molecule.shape[0]*percentage_training) &
                                   (molecule['index'] < molecule.shape[0]*(percentage_training+percentage_validation)))
molecule_testing = molecule.where('molecule_testing', 
                                   molecule['index'] > molecule.shape[0]*(percentage_training+percentage_validation))

# %% [markdown]
# Create the data model.

# %%
ph_molecule = molecule.to_placeholder()
ph_atom = atom.to_placeholder()
ph_bond = bond.to_placeholder()
ph_gmember = gmember.to_placeholder()
ph_group = group.to_placeholder()

ph_molecule.join(
    ph_atom,
    join_key = 'molecule_id'
)
ph_atom.join(
    ph_bond,
    join_key = 'atom_id'
)
ph_atom.join(
    ph_bond,
    join_key = 'atom_id',
    other_join_key = 'atom_id2'
)
ph_atom.join(
    ph_gmember,
    join_key = 'atom_id'
)
ph_gmember.join(
    ph_group,
    join_key = 'group_id'
)

# %% [markdown]
# Construct the feature engineerer, feature selector, and predictor.

# %%
feature_selector = getml.predictors.XGBoostRegressor(
    booster = 'gblinear',
    n_estimators = 60,
    n_jobs = 6,
    max_depth = 7,
    reg_lambda = 500
)

predictor = getml.predictors.XGBoostRegressor(
    booster = 'gblinear',
    n_estimators = 60,
    n_jobs = 6,
    max_depth = 7,
    reg_lambda = 500
)

## -------------------------------------------------------------------

## Construct the base model.
base_model = getml.models.RelboostModel(
    name = 'base',
    population = ph_molecule,
    peripheral = [ph_atom, ph_gmember, ph_group, ph_bond],
    loss_function = getml.models.loss_functions.SquareLoss(),
    num_features = 50,
    num_subfeatures = 10,
    feature_selector = feature_selector,
    predictor = predictor,
    num_threads = 3
).send()

# %% [markdown]
# Perform the initial training

# %%
base_model.fit(population_table=molecule_training,
              peripheral_tables=[atom, gmember, group, bond])
# Out:
# Loaded data. Features are now being trained...
# Trained model.
# Time taken: 0h:0m:23.09367
# RelboostModel:
#   type: RelboostModel
#   allow_null_weights: False
#   delta_t: 0
#   feature_selector: XGBoostRegressor:
#     type: XGBoostRegressor
#     booster: gblinear
#     colsample_bylevel: 1
#     colsample_bytree: 1
#     learning_rate: 0.1
#     gamma: 0
#     max_delta_step: 0
#     max_depth: 7
#     min_child_weights: 1
#     n_estimators: 60
#     normalize_type: tree
#     num_parallel_tree: 1
#     n_jobs: 6
#     objective: reg:squarederror
#     one_drop: False
#     rate_drop: 0
#     reg_alpha: 0
#     reg_lambda: 500
#     sample_type: uniform
#     silent: True
#     skip_drop: 0
#     subsample: 1
#   gamma: 0
#   include_categorical: False
#   loss_function: SquareLoss
#   max_depth: 3
#   min_num_samples: 1
#   name: base
#   num_features: 50
#   num_subfeatures: 10
#   num_threads: 3
#   peripheral (list):
#     Placeholder:
#       name: atom
#       categorical: ['type']
#       numerical: []
#       join_keys: ['atom_id', 'molecule_id']
#       targets: []
#       time_stamps: []
#       join_keys_used: []
#       other_join_keys_used: []
#       time_stamps_used: []
#       other_time_stamps_used: []
#       upper_time_stamps_used: []
#       joined_tables (list): []
#     Placeholder:
#       name: gmember
#       categorical: []
#       numerical: []
#       join_keys: ['atom_id', 'group_id']
#       targets: []
#       time_stamps: []
#       join_keys_used: []
#       other_join_keys_used: []
#       time_stamps_used: []
#       other_time_stamps_used: []
#       upper_time_stamps_used: []
#       joined_tables (list): []
#     Placeholder:
#       name: group
#       categorical: ['type']
#       numerical: []
#       join_keys: ['group_id']
#       targets: []
#       time_stamps: []
#       join_keys_used: []
#       other_join_keys_used: []
#       time_stamps_used: []
#       other_time_stamps_used: []
#       upper_time_stamps_used: []
#       joined_tables (list): []
#     Placeholder:
#       name: bond
#       categorical: ['type']
#       numerical: []
#       join_keys: ['atom_id', 'atom_id2']
#       targets: []
#       time_stamps: []
#       join_keys_used: []
#       other_join_keys_used: []
#       time_stamps_used: []
#       other_time_stamps_used: []
#       upper_time_stamps_used: []
#       joined_tables (list): []
#   population (Placeholder):
#     name: molecule_training
#     categorical: []
#     numerical: ['mweight', 'activity']
#     join_keys: ['molecule_id']
#     targets: ['logp']
#     time_stamps: []
#     join_keys_used: ['molecule_id']
#     other_join_keys_used: ['molecule_id']
#     time_stamps_used: ['']
#     other_time_stamps_used: ['']
#     upper_time_stamps_used: ['']
#     joined_tables (list):
#       Placeholder:
#         name: atom
#         categorical: ['type']
#         numerical: []
#         join_keys: ['atom_id', 'molecule_id']
#         targets: []
#         time_stamps: []
#         join_keys_used: ['atom_id', 'atom_id', 'atom_id']
#         other_join_keys_used: ['atom_id', 'atom_id2', 'atom_id']
#         time_stamps_used: ['', '', '']
#         other_time_stamps_used: ['', '', '']
#         upper_time_stamps_used: ['', '', '']
#         joined_tables (list):
#           Placeholder:
#             name: bond
#             categorical: ['type']
#             numerical: []
#             join_keys: ['atom_id', 'atom_id2']
#             targets: []
#             time_stamps: []
#             join_keys_used: []
#             other_join_keys_used: []
#             time_stamps_used: []
#             other_time_stamps_used: []
#             upper_time_stamps_used: []
#             joined_tables (list): []
#           Placeholder:
#             name: bond
#             categorical: ['type']
#             numerical: []
#             join_keys: ['atom_id', 'atom_id2']
#             targets: []
#             time_stamps: []
#             join_keys_used: []
#             other_join_keys_used: []
#             time_stamps_used: []
#             other_time_stamps_used: []
#             upper_time_stamps_used: []
#             joined_tables (list): []
#           Placeholder:
#             name: gmember
#             categorical: []
#             numerical: []
#             join_keys: ['atom_id', 'group_id']
#             targets: []
#             time_stamps: []
#             join_keys_used: ['group_id']
#             other_join_keys_used: ['group_id']
#             time_stamps_used: ['']
#             other_time_stamps_used: ['']
#             upper_time_stamps_used: ['']
#             joined_tables (list):
#               Placeholder:
#                 name: group
#                 categorical: ['type']
#                 numerical: []
#                 join_keys: ['group_id']
#                 targets: []
#                 time_stamps: []
#                 join_keys_used: []
#                 other_join_keys_used: []
#                 time_stamps_used: []
#                 other_time_stamps_used: []
#                 upper_time_stamps_used: []
#                 joined_tables (list): []
#   predictor: XGBoostRegressor:
#     type: XGBoostRegressor
#     booster: gblinear
#     colsample_bylevel: 1
#     colsample_bytree: 1
#     learning_rate: 0.1
#     gamma: 0
#     max_delta_step: 0
#     max_depth: 7
#     min_child_weights: 1
#     n_estimators: 60
#     normalize_type: tree
#     num_parallel_tree: 1
#     n_jobs: 6
#     objective: reg:squarederror
#     one_drop: False
#     rate_drop: 0
#     reg_alpha: 0
#     reg_lambda: 500
#     sample_type: uniform
#     silent: True
#     skip_drop: 0
#     subsample: 1
#   reg_lambda: 0
#   sampling_factor: 1
#   seed: None
#   session_name:
#   share_selected_features: 0
#   shrinkage: 0.1
#   silent: False
#   target_num: 0
#   units: {}
#   use_timestamps: True

# %%
base_model.score(population_table=molecule_training,
                peripheral_tables=[atom, gmember, group, bond])
# Out:
# {'mae': [1.2180083494651608],
#  'rmse': [1.586045027671965],
#  'rsquared': [0.5255422957520174]}

# %% [markdown]
# Perform a Gaussian hyperparameter optimization to find the best possible set of hyperparameters.

# %%
## Build a parameter space to search in
param_space = dict()

param_space["max_depth"] = [1, 10]
param_space["min_num_samples"] = [10, 100]
param_space["num_features"] = [10, 100]
param_space["reg_lambda"] = [0.01, 0.3]
param_space["share_selected_features"] = [0.3, 1.0]
param_space["shrinkage"] = [0.01, 0.4]

# Any hyperparameters that relate to the predictor
# are preceded by "predictor_".
param_space["predictor_n_estimators"] = [40, 140]
param_space["predictor_max_depth"] = [3, 15]
param_space["predictor_reg_lambda"] = [0.0, 1000.0]

## -------------------------------------------------------------------

## Start the hyperparameter optimization.
gauss_search = getml.hyperopt.GaussianHyperparameterSearch(
    model = base_model,
    param_space = param_space,
    n_iter = 120,
    ratio_iter = 0.8
)

gauss_search.fit(
  population_table_training = molecule_training,
  population_table_validation = molecule_validation,
  peripheral_tables = [atom, gmember, group, bond]
)
# Out:
# Launched hyperparameter optimization...

# %%
res_scores = gauss_search.get_scores()

res_scores
# Out:
# {'2020-03-09T17-53-00-hyperopt-gaussian-relboost-001': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1655486180458532],
#   'rmse': [1.5158329396449357],
#   'rsquared': [0.4722639088313854]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-002': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.269978395332524],
#   'rmse': [1.6272371019386307],
#   'rsquared': [0.4340706243773536]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-003': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2488222667906013],
#   'rmse': [1.6003441002819223],
#   'rsquared': [0.46596461952705653]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-004': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1903429721608567],
#   'rmse': [1.543199832806225],
#   'rsquared': [0.4315008038432993]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-005': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1872036668989385],
#   'rmse': [1.5376077827976145],
#   'rsquared': [0.44725076382075235]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-006': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1976452041555328],
#   'rmse': [1.5496068518956927],
#   'rsquared': [0.4393959642898051]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-007': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2520289562072278],
#   'rmse': [1.6083025527409274],
#   'rsquared': [0.4351281898147003]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-008': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2091710520968018],
#   'rmse': [1.5589852187765885],
#   'rsquared': [0.4568724889510832]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-009': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1881519407401844],
#   'rmse': [1.5429910741201134],
#   'rsquared': [0.43023578125702516]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-010': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.200640995414168],
#   'rmse': [1.5535064634663471],
#   'rsquared': [0.43475223607117724]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-011': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2458197402071063],
#   'rmse': [1.6030180657733926],
#   'rsquared': [0.4330964340254688]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-012': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1651264832343577],
#   'rmse': [1.519489135742937],
#   'rsquared': [0.4474104112614573]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-013': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1843898442056437],
#   'rmse': [1.5372189392602649],
#   'rsquared': [0.4338498454617423]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-014': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1835003611482213],
#   'rmse': [1.5342370903734643],
#   'rsquared': [0.45375101285876307]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-015': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2599997065391064],
#   'rmse': [1.6149952254758464],
#   'rsquared': [0.448176645556387]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-016': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2364217561556965],
#   'rmse': [1.5913313287800879],
#   'rsquared': [0.4340571868684889]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-017': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2100119176323025],
#   'rmse': [1.562762442426983],
#   'rsquared': [0.4445434871941329]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-018': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2972257506994547],
#   'rmse': [1.6566226370192123],
#   'rsquared': [0.44216429223462167]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-019': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1906382969868028],
#   'rmse': [1.5420619977987113],
#   'rsquared': [0.4408841033983585]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-020': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2147038598708157],
#   'rmse': [1.5670476067909898],
#   'rsquared': [0.4534201561235905]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-021': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2423023121445262],
#   'rmse': [1.5977633368899145],
#   'rsquared': [0.43374945086919087]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-022': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1537141275994565],
#   'rmse': [1.496591102193852],
#   'rsquared': [0.4848056147278206]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-023': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2705400183171396],
#   'rmse': [1.6282681889600472],
#   'rsquared': [0.44741252481603]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-024': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2469121351359798],
#   'rmse': [1.6003143500752586],
#   'rsquared': [0.45542535254818794]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-025': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1682587271855194],
#   'rmse': [1.5215917983257177],
#   'rsquared': [0.44374773409212565]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-026': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.178407406954117],
#   'rmse': [1.5345527418792428],
#   'rsquared': [0.4293652413225019]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-027': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.173417080184559],
#   'rmse': [1.5272994588056736],
#   'rsquared': [0.4401504601307632]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-028': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.15585010934759],
#   'rmse': [1.502499971139846],
#   'rsquared': [0.49473743310864216]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-029': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1938811097616024],
#   'rmse': [1.5439976240254285],
#   'rsquared': [0.44786922397321466]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-030': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.200764627957049],
#   'rmse': [1.5516620813576671],
#   'rsquared': [0.45039508399112566]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-031': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1586664847385728],
#   'rmse': [1.497735872255126],
#   'rsquared': [0.4838828835333692]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-032': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1178978474051857],
#   'rmse': [1.4558146920903405],
#   'rsquared': [0.5099029616713625]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-033': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.267731569549183],
#   'rmse': [1.6240424812406289],
#   'rsquared': [0.4344277730820005]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-034': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1764147155078835],
#   'rmse': [1.5298133767538444],
#   'rsquared': [0.43819623700387067]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-035': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2398155725149456],
#   'rmse': [1.59613191545672],
#   'rsquared': [0.4334576802139321]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-036': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.184031371569927],
#   'rmse': [1.5333327003320216],
#   'rsquared': [0.4516745589086549]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-037': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2110871155173684],
#   'rmse': [1.5637462369404111],
#   'rsquared': [0.45019883755789525]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-038': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1503632404774788],
#   'rmse': [1.4871984011124615],
#   'rsquared': [0.5357988253841149]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-039': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2383452817540104],
#   'rmse': [1.5825664650591673],
#   'rsquared': [0.5118930048703828]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-040': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2127961500191387],
#   'rmse': [1.5677685172831048],
#   'rsquared': [0.4341821452574286]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-041': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1549544911031362],
#   'rmse': [1.478052882031818],
#   'rsquared': [0.6153794076209703]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-042': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.190847272343105],
#   'rmse': [1.5440871597858872],
#   'rsquared': [0.4319299743047426]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-043': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1679136884065315],
#   'rmse': [1.523195562256283],
#   'rsquared': [0.437683650114147]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-044': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2615459952531032],
#   'rmse': [1.6164598085016229],
#   'rsquared': [0.4462280056086758]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-045': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2134524155546111],
#   'rmse': [1.5668183334195858],
#   'rsquared': [0.43660520072219344]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-046': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2599153711177677],
#   'rmse': [1.616687607178101],
#   'rsquared': [0.43611950394779014]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-047': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1962310375990683],
#   'rmse': [1.5495581619117185],
#   'rsquared': [0.43495826677201666]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-048': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2331173989213535],
#   'rmse': [1.5872682030268124],
#   'rsquared': [0.44425446867532]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-049': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.188362848464353],
#   'rmse': [1.5429210551116856],
#   'rsquared': [0.4335453648312902]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-050': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1998853674641354],
#   'rmse': [1.5525475507041218],
#   'rsquared': [0.43456174308394785]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-051': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.190078295896082],
#   'rmse': [1.543221739791164],
#   'rsquared': [0.4313736994202312]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-052': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.218689058415683],
#   'rmse': [1.5677663563574],
#   'rsquared': [0.49840173583577374]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-053': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.160595175145584],
#   'rmse': [1.5156290867879392],
#   'rsquared': [0.4443333449266865]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-054': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.241068171983883],
#   'rmse': [1.5966182214484037],
#   'rsquared': [0.4491983222396347]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-055': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.176273384800663],
#   'rmse': [1.5305681825813475],
#   'rsquared': [0.4413897137741591]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-056': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1624942015718522],
#   'rmse': [1.514508261857072],
#   'rsquared': [0.4506329811229555]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-057': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.267752441476892],
#   'rmse': [1.6245081444022502],
#   'rsquared': [0.4368746017476528]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-058': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1644059631559576],
#   'rmse': [1.5165276028155867],
#   'rsquared': [0.44892250047333054]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-059': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2095941972438193],
#   'rmse': [1.5629270869442373],
#   'rsquared': [0.4476317856505242]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-060': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.213008620621245],
#   'rmse': [1.5656241296639302],
#   'rsquared': [0.4462968987734061]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-061': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1874305611775238],
#   'rmse': [1.5388513912015087],
#   'rsquared': [0.43904304088958235]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-062': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1947931277899086],
#   'rmse': [1.5484742427927167],
#   'rsquared': [0.43385210017790454]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-063': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2092323264957938],
#   'rmse': [1.5621464893960217],
#   'rsquared': [0.43840200876974955]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-064': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2055160997826369],
#   'rmse': [1.5586027960958775],
#   'rsquared': [0.4378152847837798]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-065': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1832311828931166],
#   'rmse': [1.5265441078269224],
#   'rsquared': [0.47109458029662354]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-066': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.171980377185491],
#   'rmse': [1.5268272475646087],
#   'rsquared': [0.43636669005991263]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-067': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2151347727540092],
#   'rmse': [1.5657289454856673],
#   'rsquared': [0.45482442698722736]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-068': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2360378095250066],
#   'rmse': [1.5918752460971248],
#   'rsquared': [0.4323603864126416]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-069': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2566665559344816],
#   'rmse': [1.61322162146969],
#   'rsquared': [0.4372944881079177]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-070': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1899976169621496],
#   'rmse': [1.5347264593824541],
#   'rsquared': [0.47061956390421683]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-071': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2071999533382456],
#   'rmse': [1.5531052561599936],
#   'rsquared': [0.49529318650259774]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-072': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2576657858601317],
#   'rmse': [1.6152964572357158],
#   'rsquared': [0.43840232792058137]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-073': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1906428762424133],
#   'rmse': [1.5436970966071464],
#   'rsquared': [0.4361348240803624]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-074': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2420153780925414],
#   'rmse': [1.596891619706658],
#   'rsquared': [0.436910086635975]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-075': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1600827249479875],
#   'rmse': [1.5027131038695725],
#   'rsquared': [0.48089970613382205]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-076': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2644068784478264],
#   'rmse': [1.6188840543638425],
#   'rsquared': [0.46275085894210954]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-077': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2039666652679435],
#   'rmse': [1.5566392732262098],
#   'rsquared': [0.4403945870063283]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-078': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1500041762987765],
#   'rmse': [1.4862616849312253],
#   'rsquared': [0.5159769094148329]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-079': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1950256628460347],
#   'rmse': [1.531425172056897],
#   'rsquared': [0.5278085292662597]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-080': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.164038388670226],
#   'rmse': [1.5180416712615912],
#   'rsquared': [0.4431709015726515]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-081': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1827494294555092],
#   'rmse': [1.5351853688106563],
#   'rsquared': [0.4373577202895252]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-082': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1743162420060893],
#   'rmse': [1.521997229427984],
#   'rsquared': [0.46480454608393407]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-083': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.074913830050715],
#   'rmse': [1.3913099668710258],
#   'rsquared': [0.6609523496043125]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-084': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1815022986612196],
#   'rmse': [1.5336773537030557],
#   'rsquared': [0.43975517509164586]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-085': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2429233128347508],
#   'rmse': [1.5993869739813238],
#   'rsquared': [0.43812218117398616]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-086': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.1549405549779344],
#   'rmse': [1.5037120903899532],
#   'rsquared': [0.4688527223857184]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-087': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.230330985033953],
#   'rmse': [1.584567245974303],
#   'rsquared': [0.4340872299957198]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-088': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.281412957803702],
#   'rmse': [1.6393649859445085],
#   'rsquared': [0.4367122784718352]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-089': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2040761023391904],
#   'rmse': [1.5572736083032133],
#   'rsquared': [0.433532006745109]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-090': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.197802853289945],
#   'rmse': [1.5509831263264728],
#   'rsquared': [0.43324346350119947]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-091': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2073561694886943],
#   'rmse': [1.5582023506049587],
#   'rsquared': [0.44393922487059034]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-092': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2208248337698564],
#   'rmse': [1.575864475719955],
#   'rsquared': [0.4385713324124739]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-093': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.175745313667956],
#   'rmse': [1.5271393734926417],
#   'rsquared': [0.5018784094675387]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-094': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2456667564239026],
#   'rmse': [1.6024625459224247],
#   'rsquared': [0.4430035629088925]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-095': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.2269078494295655],
#   'rmse': [1.5785915643114092],
#   'rsquared': [0.46174068396225226]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-096': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [1.163681890346385],
#   'rmse': [1.5207390518732269],
#   'rsquared': [0.4375048344256279]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-097': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5665383070955677],
#   'rmse': [0.7433542773465832],
#   'rsquared': [0.8651682348549377]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-098': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6872655935346345],
#   'rmse': [0.8783773986842067],
#   'rsquared': [0.8018136188228089]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-099': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.641753554204364],
#   'rmse': [0.8332148662351132],
#   'rsquared': [0.8233029074416511]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-100': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5562618019606599],
#   'rmse': [0.708798629875534],
#   'rsquared': [0.8733586794423057]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-101': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5850987767437358],
#   'rmse': [0.7529098405318345],
#   'rsquared': [0.8546519737284242]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-102': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5970197159401429],
#   'rmse': [0.7465777678150688],
#   'rsquared': [0.8600055898162876]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-103': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6124889977184343],
#   'rmse': [0.7994783407711152],
#   'rsquared': [0.8352046944733408]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-104': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6046334583211092],
#   'rmse': [0.8189940181315619],
#   'rsquared': [0.8265928469319052]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-105': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6943249777437729],
#   'rmse': [0.959443591126535],
#   'rsquared': [0.7588841760565213]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-106': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6129154220701738],
#   'rmse': [0.8389119243120656],
#   'rsquared': [0.8211397805104115]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-107': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6174319237139491],
#   'rmse': [0.789746602286671],
#   'rsquared': [0.8470143999738725]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-108': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.631254003333089],
#   'rmse': [0.8115680777136924],
#   'rsquared': [0.8342601525360519]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-109': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6232381730315127],
#   'rmse': [0.811003246070777],
#   'rsquared': [0.8322051021951534]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-110': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6050214128067465],
#   'rmse': [0.7869337772866727],
#   'rsquared': [0.8408474810688338]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-111': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6143339291914013],
#   'rmse': [0.7923629486669541],
#   'rsquared': [0.8420133164432935]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-112': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5510271721452843],
#   'rmse': [0.7136519772435154],
#   'rsquared': [0.8713430210638584]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-113': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5322759218054055],
#   'rmse': [0.7115767463995804],
#   'rsquared': [0.869567365883451]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-114': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5669050564000636],
#   'rmse': [0.7327255066277514],
#   'rsquared': [0.8653093668816285]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-115': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5811026547720404],
#   'rmse': [0.7514530995535132],
#   'rsquared': [0.8595107517296252]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-116': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6116842056534908],
#   'rmse': [0.8009387619546472],
#   'rsquared': [0.8387883128878205]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-117': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.6317330144391752],
#   'rmse': [0.812905848336267],
#   'rsquared': [0.8303105943814473]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-118': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.552325565715631],
#   'rmse': [0.7473463710713164],
#   'rsquared': [0.8572027682502942]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-119': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5220732480397933],
#   'rmse': [0.7216248084949526],
#   'rsquared': [0.867309339521217]},
#  '2020-03-09T17-53-00-hyperopt-gaussian-relboost-120': {'accuracy': [],
#   'auc': [],
#   'cross_entropy': [],
#   'mae': [0.5956634526065107],
#   'rmse': [0.7592776830110157],
#   'rsquared': [0.8576124757080185]}}
